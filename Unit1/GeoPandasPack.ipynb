# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import contextily as ctx

# %%
world_gdf = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
world_gdf
world_gdf.crs
# Out:
# C:\Users\daara\AppData\Local\Temp\ipykernel_19292\1005900677.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_gdf = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world_gdf['pop_density'] = world_gdf.pop_est/world_gdf.area * 10**6
world_gdf.sort_values(ascending=False, by='pop_density')
# Out:
# C:\Users\daara\AppData\Local\Temp\ipykernel_19292\196813742.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world_gdf['pop_density'] = world_gdf.pop_est/world_gdf.area * 10**6
#          pop_est                continent                    name iso_a3  \
# 99   163046161.0                     Asia              Bangladesh    BGD
# 79     4685306.0                     Asia               Palestine    PSE
# 140   23568378.0                     Asia                  Taiwan    TWN
# 77     6855713.0                     Asia                 Lebanon    LBN
# 169   12626950.0                   Africa                  Rwanda    RWA
# ..           ...                      ...                     ...    ...
# 144     361313.0                   Europe                 Iceland    ISL
# 20        3398.0            South America            Falkland Is.    FLK
# ...

# %%
world_gdf.plot('pop_density', legend=True, figsize=(20, 11))
# Out:
# <AxesSubplot: >

# %%
norm = matplotlib.colors.LogNorm(vmin=world_gdf.pop_density.min(), vmax=world_gdf.pop_density.max())

world_gdf.to_crs('epsg:4326').plot("pop_density", figsize=(20,11), legend=True, norm=norm)
# Out:
# <AxesSubplot: >

# %%
deaths = gpd.read_file('SnowGIS/Cholera_Deaths.shp')
pumps = gpd.read_file('SnowGIS/Pumps.shp')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: SnowGIS/Cholera_Deaths.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Input In [15], in <module>
# ----> 1 deaths = gpd.read_file('SnowGIS/Cholera_Deaths.shp')
#       2 pumps = gpd.read_file('SnowGIS/Pumps.shp')
#
# File c:\Users\daara\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\io\file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
# ...

# %%
deaths.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.01, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
ax = deaths.plot(column="Count", edgecolor='k', alpha=0.7, legend=True, figsize=(10, 10))

# %%
ax = deaths.plot(column="Count", edgecolor='k', alpha=0.7, legend=True, figsize=(10, 10))
pumps.plot(ax=ax, marker='x', color='r', markersize=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 ax = deaths.plot(column="Count", edgecolor='k', alpha=0.7, legend=True, figsize=(10, 10))
#       2 pumps.plot(marker='x', color='r', markersize=50)
#
# NameError: name 'deaths' is not defined

# %%
ax = deaths.plot(column="Count", edgecolor='k', alpha=0.7, legend=True, figsize=(20, 20))
pumps.plot(ax=ax, marker='x', color='r', markersize=50)

ctx.add_basemap(ax, crs=deaths.crs.to_string())

# %%
ax = deaths.plot(column="Count", edgecolor='k', alpha=0.7, legend=True, figsize=(20, 20))
pumps.plot(ax=ax, marker='x', color='r', markersize=50)

ctx.add_basemap(ax, crs=deaths.crs.to_string(), source="SnowGIS/SnowMap.tif")

# %%
gdf_districts = gpd.read_file()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 gdf_districts = gpd.read_file(gdfs['districts'])
#
# NameError: name 'gdfs' is not defined
